# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ## Extracción de datos desde la API

# %%
tender = pd.read_csv('../Data_output/tender.csv')
# Out:
# C:\Users\kuinc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (13,14,15,16,17,19,20,21,23,24,25,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
result = [] #Lista con los resultados de la extracción de la API

# %%
slice_tender = tender['ocid'].loc[391084:]
slice_tender.nunique()
# Out:
# 206141

# %%
url = "https://datosabiertos.compraspublicas.gob.ec/PLATAFORMA/api/record"
for i,ocid in enumerate(slice_tender):
    params = {"ocid": ocid}
    response = requests.get(url,params)
    content = response.content
    if response.status_code == 200:
        data = json.loads(content)
        result.append(data)
        print(str(i)+"-> "+ocid)
    else:
        print(response.status_code,"\n",ocid)
        
    with open('../Data_input/result6.json', 'w') as fp:
        json.dump(result, fp)
# Out:
# 0-> ocds-5wno2w-CE-20200001883770-110713
# 1-> ocds-5wno2w-CE-20200001883771-110713
# 2-> ocds-5wno2w-CE-20200001883772-110713
# 3-> ocds-5wno2w-CE-20200001883773-110713
# 4-> ocds-5wno2w-CE-20200001883774-110713
# 5-> ocds-5wno2w-CE-20200001883775-10287
# 6-> ocds-5wno2w-CE-20200001883776-10287
# 7-> ocds-5wno2w-CE-20200001883777-10287
# 8-> ocds-5wno2w-CE-20200001883778-10287
# 9-> ocds-5wno2w-CE-20200001883779-10287
# 10-> ocds-5wno2w-CE-20200001883780-10287
# 11-> ocds-5wno2w-CE-20200001883781-10287
# 12-> ocds-5wno2w-CE-20200001883782-10287
# 13-> ocds-5wno2w-CE-20200001883783-10287
# 14-> ocds-5wno2w-CE-20200001883784-10287
# 15-> ocds-5wno2w-CE-20200001883785-10287
# 16-> ocds-5wno2w-CE-20200001883786-10287
# 17-> ocds-5wno2w-CE-20200001883787-62743
# 18-> ocds-5wno2w-CE-20200001883797-17945
# 19-> ocds-5wno2w-CE-20200001883798-17945
# 20-> ocds-5wno2w-CE-20200001883799-17945
# 21-> ocds-5wno2w-CE-20200001883800-17945
# 22-> ocds-5wno2w-CE-20200001883801-17945
# ...

# %%
len(result)
