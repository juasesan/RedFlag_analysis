# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ## Extracción de datos desde la API

# %%
tender = pd.read_csv('../Data_output/tender.csv')
# Out:
# C:\Users\kuinc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (13,14,15,16,17,19,20,21,23,24,25,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
result = [] #Lista con los resultados de la extracción de la API

# %%
slice_tender = tender['ocid'].loc[392000:]
slice_tender.nunique()
# Out:
# 205225

# %%
url = "https://datosabiertos.compraspublicas.gob.ec/PLATAFORMA/api/record"
for i,ocid in enumerate(slice_tender):
    params = {"ocid": ocid}
    response = requests.get(url,params)
    content = response.content
    if response.status_code == 200:
        data = json.loads(content)
        result.append(data)
        print(str(i)+"-> "+ocid)
    else:
        print(response.status_code,"\n",ocid)
        
    with open('../Data_input/result7.json', 'w') as fp:
        json.dump(result, fp)
# Out:
# 0-> ocds-5wno2w-CE-20200001885204-353960
# 1-> ocds-5wno2w-CE-20200001885205-353960
# 2-> ocds-5wno2w-CE-20200001885206-353960
# 3-> ocds-5wno2w-CE-20200001885207-353960
# 4-> ocds-5wno2w-CE-20200001885210-3268
# 5-> ocds-5wno2w-CE-20200001885211-346777
# 6-> ocds-5wno2w-CE-20200001885213-346777
# 7-> ocds-5wno2w-CE-20200001885214-346777
# 8-> ocds-5wno2w-CE-20200001885215-346777
# 9-> ocds-5wno2w-CE-20200001885216-346777
# 10-> ocds-5wno2w-CE-20200001885217-346777
# 11-> ocds-5wno2w-CE-20200001885218-346777
# 12-> ocds-5wno2w-CE-20200001885219-385338
# 13-> ocds-5wno2w-CE-20200001885220-385338
# 14-> ocds-5wno2w-CE-20200001885221-385338
# 15-> ocds-5wno2w-CE-20200001885222-385338
# 16-> ocds-5wno2w-CE-20200001885223-385338
# 17-> ocds-5wno2w-CE-20200001885224-385338
# 18-> ocds-5wno2w-CE-20200001885225-385338
# 19-> ocds-5wno2w-CE-20200001885226-385338
# 20-> ocds-5wno2w-CE-20200001885229-104101
# 21-> ocds-5wno2w-CE-20200001885230-104101
# 22-> ocds-5wno2w-CE-20200001885231-104101
# ...

# %%
len(result)
